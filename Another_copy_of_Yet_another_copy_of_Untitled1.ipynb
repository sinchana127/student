# %% [markdown]
# <a href="https://colab.research.google.com/github/sinchana127/student/blob/main/Another_copy_of_Yet_another_copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
result =a+b
mul=a*b
div=a/b
print(result)
print(mul)
print(div)
# Out:
# [5 7 9]
# [ 4 10 18]
# [0.25 0.4  0.5 ]

# %% [markdown]
# # 2.map with numpy array

# %%
import numpy as np
a=np.array([4,6,2])
result=list(map(lambda x:x**3,a))
print(result)
# Out:
# [64, 216, 8]

# %%
import numpy as np
b=np.array([1,9,7,6,3])
result=list(filter(lambda x:x % 3==0,b))
print(result)
# Out:
# [9, 6, 3]

# %% [markdown]
# # 4.dataframe

# %%
import pandas as pd
data={'category':['A','B','A','B','A'],
'value':[12,34,23,16,10]}
df=pd.DataFrame(data)
print(df)
# Out:
#   category  value
# 0        A     12
# 1        B     34
# 2        A     23
# 3        B     16
# 4        A     10

# %% [markdown]
# # 5.grouping and aggregation

# %%
import pandas as pd
grouped=df.groupby('category')
result=grouped.mean()
print(result)
# Out:
#           value
# category
# A          15.0
# B          25.0

# %% [markdown]
# # 5.time series data

# %% [markdown]
# # numpy code using matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('sine wave')
plt.grid(True)
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/student-dataset.csv")
print(df.head())
# Out:
#    id             name               nationality                 city  \
# 0   0        Kiana Lor                     China               Suzhou
# 1   1   Joshua Lonaker  United States of America        Santa Clarita
# 2   2    Dakota Blanco  United States of America              Oakland
# 3   3  Natasha Yarusso  United States of America        Castro Valley
# 4   4   Brooke Cazares                    Brazil  São José dos Campos
#
#    latitude  longitude gender  ethnic.group  age  english.grade  math.grade  \
# 0     31.31     120.62      F           NaN   22            3.5         3.7
# 1     34.39    -118.54      M           NaN   22            2.9         3.2
# 2     37.80    -122.27      F           NaN   22            3.9         3.8
# 3     37.69    -122.09      F           NaN   20            3.3         2.8
# 4    -23.18     -45.88      F           NaN   21            3.7         2.6
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %% [markdown]
# # pivot

# %%
import pandas as pd
data={'Date':['2023-01-01','2023-01-02','2023-01-01','2023-01-02'],
      'Category':['A','A','B','B'],
      'Value':[10,20,30,40]}
df=pd.DataFrame(data)
print(df)
# Out:
#          Date Category  Value
# 0  2023-01-01        A     10
# 1  2023-01-02        A     20
# 2  2023-01-01        B     30
# 3  2023-01-02        B     40

# %%
import pandas as pd

# %% [markdown]
# # map using numpy

# %%
import numpy as np
a=np.array([4,6,2])
result=list(map(lambda x:x**3,a))
print(result)
# Out:
# [64, 216, 8]

# %%
import numpy as np
arr=[2,4,6,8]
arr=list(map(lambda x:x*x,arr))
print(arr)
# Out:
# [4, 16, 36, 64]

# %% [markdown]
# # filter using numpy

# %%
import numpy as np
b=np.array([1,9,7,6,3])
result=list(filter(lambda x:x % 3==0,b))
print(result)
# Out:
# [9, 6, 3]

# %% [markdown]
# # reduce using numpy

# %%
import numpy as np
from functools import reduce
arr=np.array([1,2,3,4,5])
sum_arr=reduce(lambda x,y:x+y,arr)
mul_arr=reduce(lambda x,y:x*y,arr)
print(sum_arr)
print(mul_arr)
# Out:
# 15
# 120

# %% [markdown]
# ## lambda using numpy

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
squared_arr=np.array(list(map(lambda x:x**2,arr)))
doubled_arr=np.array(list(map(lambda x:x*3,arr)))
increment_arr=np.array(list(map(lambda x:x+1,arr)))
print(squared_arr)
print(doubled_arr)
print(increment_arr)
# Out:
# [ 1  4  9 16 25]
# [ 3  6  9 12 15]
# [2 3 4 5 6]

# %% [markdown]
# # map using pandas

# %%
import pandas as pd
df=pd.DataFrame({'A':[1,2,3,4,5]})
value=['low','medium','high','very high','extremely high']
df['category']=df['A'].map({1:value[0],2:value[1],3:value[2],4:value[3],5:value[4]})
print(df)
# Out:
#    A        category
# 0  1             low
# 1  2          medium
# 2  3            high
# 3  4       very high
# 4  5  extremely high

# %% [markdown]
# # filter using pandas

# %%
import pandas as pd
df=pd.DataFrame({'A':[1,2,3,4,5],'B':[10,20,30,40,50]})
filtered_df=df[df['A']>3]
print(filtered_df)
# Out:
#    A   B
# 3  4  40
# 4  5  50

# %%
import pandas as pd
df=pd.DataFrame({'A':[1,2,3,4,5],'B':[10,20,30,40,50]})
filtered_df=df[df['A'].isin([2,4])]
print(filtered_df)
# Out:
#    A   B
# 1  2  20
# 3  4  40

# %% [markdown]
# # reduce using pandas

# %%
from functools import reduce
import pandas as pd
s=pd.series([1,2,3,4,5])
result=s.reduce(np.prod)
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-6d85b4e2fc33> in <cell line: 3>()
#       1 from functools import reduce
#       2 import pandas as pd
# ----> 3 s=pd.series([1,2,3,4,5])
#       4 result=s.reduce(np.prod)
#       5 print(result)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %% [markdown]
# # lambda using pandas

# %%
import pandas as pd
df=pd.DataFrame({'A':[1,2,3,4,5]})
df['double_A']=df['A'].apply(lambda x:x*2)
print(df)
# Out:
#    A  double_A
# 0  1         2
# 1  2         4
# 2  3         6
# 3  4         8
# 4  5        10

# %%
import pandas as pd
df=pd.DataFrame({'A':[1,2,3,4,5]})
df['squared_A']=df['A'].apply(lambda x:x**2)
print(df)
# Out:
#    A  squared_A
# 0  1          1
# 1  2          4
# 2  3          9
# 3  4         16
# 4  5         25

# %% [markdown]
# # line plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # scatter plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # bar chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.bar(x,y)
plt.show()

# %% [markdown]
# # histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.random.randn(1000)
plt.hist(data,bins=30)
plt.show()

# %% [markdown]
# # pie chart

# %%
import numpy as np
import matplotlib.pyplot as plt
labels=['A','B','C']
sizes=[15,30,55]
plt.pie(sizes,labels=labels)
plt.show()

# %% [markdown]
# # text color

# %%
import pandas as pd
import matplotlib.pyplot as plt
text='hello, World'
colors=['red','green','blue','yellow','black']
fig,ax=plt.subplots()
ax.text(0.1,0.,-0.1*2,text,color=colors,fontsize=20)
ax.set_xlim([0,1])
ax.set_ylim([0,1])
ax.set_xticks([])
ax.set_yticks([])
ax.set_facecolor('purple')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-eb187de1b251> in <cell line: 6>()
#       4 colors=['red','green','blue','yellow','black']
#       5 fig,ax=plt.subplots()
# ----> 6 ax.text(0.1,0.,-0.1*2,text,color=colors,fontsize=20)
#       7 ax.set_xlim([0,1])
#       8 ax.set_ylim([0,1])
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in text(self, x, y, s, fontdict, **kwargs)
#     679             >>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))
#     680         """
# --> 681         effective_kwargs = {
#     682             'verticalalignment': 'baseline',
#     683             'horizontalalignment': 'left',
#
# TypeError: 'str' object is not a mapping

# %% [markdown]
# # visualizing proprotion

# %%
import matplotlib.pyplot as plt
categories=['category 1','category 2','category3']
proportions=[0.4,0.3,0.3]
plt.pie(proportions,labels=categories,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame ({
    'A':[1,2,3,4,5],
    'B':[5,4,3,2,1],
    'C':[2,3,4,5,6]
})
df.plot(kind='line',title='line plot')
plt.show()
df.plot(kind='bar',title='bar plot')
plt.show()
df['A'].plot(kind='hist', bins=10,title='histogram plot')
plt.show()
df.plot(kind='box',title='box plot')
plt.show()
df.plot(kind='scatter',x='A',y='B',title='scatter plot')
plt.show()
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(12,10))
df['A'].plot(ax=axes[0,0],title=('subplot 1'))
df['B'].plot(ax=axes[0,0],title=('subplot 2'))
df['C'].plot(ax=axes[0,0],title=('subplot 3'))
df.plot(kind='scatter',x='A',y='C',ax=axes[1,1],title='subplot 4')
plt.tight_layout()
plt.show()

# %% [markdown]
# # amount by category

# %%
import matplotlib.pyplot as plt
amounts=[10,20,30,40]
categories=['category 1','category 2','category 3','category 4']
fig,ax=plt.subplots()
ax.bar(categories,amounts)
ax.set_title('Amounts by category')
ax.set_xlabel('category')
ax.set_ylabel('amount')
plt.show()

# %% [markdown]
# # trend

# %%
import matplotlib.pyplot as plt
import pandas as pd
months=pd.date_range(start='2023-01-01',periods=12,freq='M')
sales=[100,120,150,130,180,200,220,250,240,280,300,320,]
plt.figure(figsize=(10,5))
plt.plot(months,sales,marker='1')
plt.title('Monthly Sale Trend')
plt.xlabel('Month')
plt.ylabel('Sales Amount')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris=sns.load_dataset("iris")
sns.pairplot(iris,hue="species")
plt.show()

# %% [markdown]
# # sampledata

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "group":["A","B","C"],
    "income":[40000,55000,60000],
    "age":[28,34,16]
}
df=pd.DataFrame(data)
df.set_index("group")[["income","age","education"]].plot(kind="bar")
plt.xlable("group")
plt.ylable("value")
plt.title("comparision of income,age and education by group")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-12ee398628f4> in <cell line: 9>()
#       7 }
#       8 df=pd.DataFrame(data)
# ----> 9 df.set_index("group")[["income","age","education"]].plot(kind="bar")
#      10 plt.xlable("group")
#      11 plt.ylable("value")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# ...

# %% [markdown]
# # visualizing uncertainity

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2.4,7.5,3.9,2.1,6.3]
y_err=[0.5,0.8,1.2,1.5,2.0]
plt.errorbar(x,y,y_err,fmt='2',label='data')
plt.title("eperimental data witn uncertai")

# %% [markdown]
# # scatter in matplotlib

# %%
import matplotlib.pyplot as plt
x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,100,86,103,87,94,78,77,85,86]
plt.scatter(x, y, c="green")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df['lunch']= df['writing score'].map(lambda x: x* 2)
print(df)
# Out:
#      gender race/ethnicity parental level of education  lunch  \
# 0    female        group B           bachelor's degree    148
# 1    female        group C                some college    176
# 2    female        group B             master's degree    186
# 3      male        group A          associate's degree     88
# 4      male        group C                some college    150
# ..      ...            ...                         ...    ...
# 995  female        group E             master's degree    190
# 996    male        group C                 high school    110
# 997  female        group C                 high school    130
# 998  female        group D                some college    154
# 999  female        group D                some college    172
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ...

# %%
filtered_d=df[df['writing score'].map(lambda x: x >= 78)]
print(filtered_d)
# Out:
#      gender race/ethnicity parental level of education  lunch  \
# 1    female        group C                some college    176
# 2    female        group B             master's degree    186
# 5    female        group B          associate's degree    156
# 6    female        group B                some college    184
# 15   female        group C            some high school    156
# ..      ...            ...                         ...    ...
# 984  female        group C            some high school    164
# 989  female        group D                some college    166
# 991  female        group B            some high school    156
# 995  female        group E             master's degree    190
# 999  female        group D                some college    172
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          69             90             88
# 2                      none          90             95             93
# ...

# %%
from functools import reduce
if not filtered_d['lunch'].empty:
  total=reduce(lambda x, y: x + y, filtered_d['lunch'])
  print(total)
else:
  print("the filtered DataFrame is empty,cannot calculate total lunch.")
# Out:
# 47874

# %%
df.sum()
# Out:
# gender                         femalefemalefemalemalemalefemalefemalemalemale...
# race/ethnicity                 group Bgroup Cgroup Bgroup Agroup Cgroup Bgrou...
# parental level of education    bachelor's degreesome collegemaster's degreeas...
# lunch                          standardstandardstandardfree/reducedstandardst...
# test preparation course        nonecompletednonenonenonenonecompletednonecomp...
# math score                                                                 66089
# reading score                                                              69169
# writing score                                                              68054
# dtype: object

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.min()
# Out:
# gender                                     female
# race/ethnicity                            group A
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                 completed
# math score                                      0
# reading score                                  17
# writing score                                  10
# dtype: object

# %%
df.max()
# Out:
# gender                                     male
# race/ethnicity                          group E
# parental level of education    some high school
# lunch                                  standard
# test preparation course                    none
# math score                                  100
# reading score                               100
# writing score                               100
# dtype: object

# %%
df.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
import pandas as pd
data=pd.read_csv("/content/StudentsPerformance.csv")
grade_map={9:'male',10:'female'}
data['gender_level']=data['gender'].map(grade_map)
print(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
import pandas as pd
path='/content/StudentsPerformance.csv'
data=pd.read_csv(path)
grouped = data.groupby('reading score')
print(grouped.agg({'math score':'sum','writing score':'sum'}))
# Out:
#                math score  writing score
# reading score
# 17                      0             10
# 23                     28             19
# 24                     38             38
# 26                     30             22
# 28                     35             27
# ...                   ...            ...
# 95                    695            740
# 96                    378            368
# 97                    437            481
# 99                    270            295
# 100                  1607           1678
#
# [72 rows x 2 columns]

# %%
import pandas as pd
data=pd.read_csv("/content/StudentsPerformance.csv")
grade_filter={11:'male',8:'female'}
data['lunch']=data['lunch'].filter(grade_filter)
print(data)
# Out:
#      gender race/ethnicity parental level of education lunch  \
# 0    female        group B           bachelor's degree   NaN
# 1    female        group C                some college   NaN
# 2    female        group B             master's degree   NaN
# 3      male        group A          associate's degree   NaN
# 4      male        group C                some college   NaN
# ..      ...            ...                         ...   ...
# 995  female        group E             master's degree   NaN
# 996    male        group C                 high school   NaN
# 997  female        group C                 high school   NaN
# 998  female        group D                some college   NaN
# 999  female        group D                some college   NaN
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/StudentsPerformance.csv")
filtered_data=data[data['writing score']<80]
print(filtered_data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 7      male        group B                some college  free/reduced
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
filtered_d=df[df['math score'].map(lambda x:x >=100)]
print(filtered_d)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# 451                    none         100             92             97
# 458                    none         100            100            100
# 623               completed         100             96             86
# ...

# %%
from functools import reduce
if not filtered_d['math score'].empty:  # Check if 'age' column is empty
    total = reduce(lambda x, y: x + y, filtered_d['math score'])
    print(total)
else:
    print("The filtered DataFrame is empty, cannot calculate total age.")
# Out:
# 700

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
filtered_d=df[df['math score'].map(lambda x: x >= 100)]
print(filtered_d)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# 451                    none         100             92             97
# 458                    none         100            100            100
# 623               completed         100             96             86
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/StudentsPerformance.csv')
df['lunch'] = df['lunch'].map(lambda x: x * 1)
print(df)
filtered_df = df[df['writing score'].map(lambda x: x >=60)]
print(filtered_df)
total = reduce(lambda x, y : x + y, filtered_df['lunch'])
print(total)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
d = pd.read_csv('/content/StudentsPerformance.csv')
d['reading score'] = d['reading score'].map(lambda x: x * 2)
print(d)
filtered_d = d[d['math score'].map(lambda x: x >=30)]
print(filtered_d)
from functools import reduce
if not filtered_d['math score'].empty: # check if lunch column is empty
    total = reduce(lambda x, y: x + y, filtered_d['math score'])
    print(total)
else:
  print("The filte red DataFrame is empty, cannot calculate total math score.")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sum()
# Out:
# gender                         femalefemalefemalemalemalefemalefemalemalemale...
# race/ethnicity                 group Bgroup Cgroup Bgroup Agroup Cgroup Bgrou...
# parental level of education    bachelor's degreesome collegemaster's degreeas...
# lunch                          standardstandardstandardfree/reducedstandardst...
# test preparation course        nonecompletednonenonenonenonecompletednonecomp...
# math score                                                                 66089
# reading score                                                              69169
# writing score                                                              68054
# dtype: object

# %%
import pandas as pd
# load the CSV file into DataFrame
d=pd.read_csv('/content/StudentsPerformance.csv')
import matplotlib.pyplot as plt
import seaborn as sns
# Set plot size
plt.figure(figsize=(20, 15))

# %%
#2. Bar plot
plt.subplot(2, 3, 2)
plt.bar(d['reading score'], d['writing score'])
plt.title("BAR PLOT")
plt.xlabel('writing score')
plt.ylabel('reading score')
# Out:
# Text(0, 0.5, 'reading score')

# %%
plt.hist(d['reading score'],bins=10,alpha=0.7,color='purple')
plt.title('Reading Score Distribution')
plt.xlabel('Reading score')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
# load the CSV file into DataFrame
d=pd.read_csv('/content/StudentsPerformance.csv')
import matplotlib.pyplot as plt
import seaborn as sns
# Set plot size
plt.figure(figsize=(20, 15))

# %%
#4 PIE CHART
plt.subplot(2,3,6)
plt.pie(d['reading score'], labels=d['lunch'], autopct='%1.1f%%')
plt.title('PIE CHART')
# Out:
# Text(0.5, 1.0, 'PIE CHART')

# %%
#1. Line plot
plt.subplot(2, 3, 1)
plt.plot(d['math score'], d['lunch'])
plt.title("LINE PLOT")
plt.xlabel('math score')
plt.ylabel('lunch')
# Out:
# Text(0, 0.5, 'lunch')

# %%
#5 box plot
plt.figure(figsize=(10,6))
d.boxplot(column=['math score'])
plt.title("BOX PLOT")
plt.ylabel('gender')
# Out:
# Text(0, 0.5, 'gender')

# %%
#4 scatter plot
plt.subplot(2,3,4)
plt.scatter(d['reading score'],d['math score'])
plt.title("SCATTER PLOT")
plt.xlabel('reading score')
plt.ylabel('math score')
# Out:
# Text(0, 0.5, 'math score')

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
import pandas as pd
df=pd.read_csv("/content/StudentsPerformance.csv")
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
import pandas as pd
df=pd.read_csv("/content/retail trade 1.csv")
print(df)
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1       RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2       RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3       RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4       RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
# 5       RTTA.SF11CA  2002.03     33853.0         NaN      F  Dollars
# 6       RTTA.SF11CA  2003.03     36284.6         NaN      F  Dollars
# 7       RTTA.SF11CA  2004.03     38184.9         NaN      F  Dollars
# 8       RTTA.SF11KA  1999.03     35371.2         NaN      F  Dollars
# 9       RTTA.SF11KA  2000.03     37506.9         NaN      F  Dollars
# 10      RTTA.SF11KA  2001.03     38269.6         NaN      F  Dollars
# 11      RTTA.SF11KA  2002.03     39423.6         NaN      F  Dollars
# 12      RTTA.SF11KA  2003.03     41403.4         NaN      F  Dollars
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1      RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2      RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3      RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4      RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
#
#    Magnitude                        Subject  \
# 0          6  Retail Trade (ANZSIC06) - RTT
# 1          6  Retail Trade (ANZSIC06) - RTT
# 2          6  Retail Trade (ANZSIC06) - RTT
# 3          6  Retail Trade (ANZSIC06) - RTT
# 4          6  Retail Trade (ANZSIC06) - RTT
#
#                                                Group         Series_title_1  \
# 0  Sales and stocks by industry, in current and c...  Core industries total
# 1  Sales and stocks by industry, in current and c...  Core industries total
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/retail trade 1.csv")
print(df)
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1       RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2       RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3       RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4       RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
# 5       RTTA.SF11CA  2002.03     33853.0         NaN      F  Dollars
# 6       RTTA.SF11CA  2003.03     36284.6         NaN      F  Dollars
# 7       RTTA.SF11CA  2004.03     38184.9         NaN      F  Dollars
# 8       RTTA.SF11KA  1999.03     35371.2         NaN      F  Dollars
# 9       RTTA.SF11KA  2000.03     37506.9         NaN      F  Dollars
# 10      RTTA.SF11KA  2001.03     38269.6         NaN      F  Dollars
# 11      RTTA.SF11KA  2002.03     39423.6         NaN      F  Dollars
# 12      RTTA.SF11KA  2003.03     41403.4         NaN      F  Dollars
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/retail-trade-survey-march-2024-quarter.zip")
print(df)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0          RTTA.SF11CA  1997.03     27070.4        NaN      F  Dollars
# 1          RTTA.SF11CA  1998.03     27748.4        NaN      F  Dollars
# 2          RTTA.SF11CA  1999.03     28216.6        NaN      F  Dollars
# 3          RTTA.SF11CA  2000.03     30204.1        NaN      F  Dollars
# 4          RTTA.SF11CA  2001.03     31641.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 26188         RTEQ.SNV  2023.03      1447.0        NaN      F    Index
# 26189         RTEQ.SNV  2023.06      1482.0        NaN      F    Index
# 26190         RTEQ.SNV  2023.09      1507.0        NaN      F    Index
# 26191         RTEQ.SNV  2023.12      1520.0        NaN      F    Index
# 26192         RTEQ.SNV  2024.03      1537.0        NaN      F    Index
#
#        Magnitude                                  Subject  \
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0      RTTA.SF11CA  1997.03     27070.4        NaN      F  Dollars          6
# 1      RTTA.SF11CA  1998.03     27748.4        NaN      F  Dollars          6
# 2      RTTA.SF11CA  1999.03     28216.6        NaN      F  Dollars          6
# 3      RTTA.SF11CA  2000.03     30204.1        NaN      F  Dollars          6
# 4      RTTA.SF11CA  2001.03     31641.6        NaN      F  Dollars          6
#
#                          Subject  \
# 0  Retail Trade (ANZSIC06) - RTT
# 1  Retail Trade (ANZSIC06) - RTT
# 2  Retail Trade (ANZSIC06) - RTT
# 3  Retail Trade (ANZSIC06) - RTT
# 4  Retail Trade (ANZSIC06) - RTT
#
#                                                Group         Series_title_1  \
# 0  Sales and stocks by industry, in current and c...  Core industries total
# 1  Sales and stocks by industry, in current and c...  Core industries total
# ...

# %%
import pandas as pd
path='/content/retail-trade-survey-march-2024-quarter.zip'
data=pd.read_csv(path)
grouped = data.groupby('Subject')
print(grouped.agg({'Series_title_1':'sum','Series_title_2':'sum'}))
# Out:
#                                                                             Series_title_1  \
# Subject
# Retail Trade (ANZSIC06) - RTT            Core industries totalCore industries totalCore...
# Retail Trade Deflators (ANZSIC06) - RTE  Supermarket and grocery storesSupermarket and ...
#
#                                                                             Series_title_2
# Subject
# Retail Trade (ANZSIC06) - RTT            Sales (operating income)Sales (operating incom...
# Retail Trade Deflators (ANZSIC06) - RTE                                                  0

# %%
import pandas as pd
# read CSV file into Dataframe
d = pd.read_csv('/content/retail-trade-survey-march-2024-quarter.zip')
d['Series_title_1'] = d['Series_title_1'].map(lambda x: x * 1)
print(d)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0          RTTA.SF11CA  1997.03     27070.4        NaN      F  Dollars
# 1          RTTA.SF11CA  1998.03     27748.4        NaN      F  Dollars
# 2          RTTA.SF11CA  1999.03     28216.6        NaN      F  Dollars
# 3          RTTA.SF11CA  2000.03     30204.1        NaN      F  Dollars
# 4          RTTA.SF11CA  2001.03     31641.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 26188         RTEQ.SNV  2023.03      1447.0        NaN      F    Index
# 26189         RTEQ.SNV  2023.06      1482.0        NaN      F    Index
# 26190         RTEQ.SNV  2023.09      1507.0        NaN      F    Index
# 26191         RTEQ.SNV  2023.12      1520.0        NaN      F    Index
# 26192         RTEQ.SNV  2024.03      1537.0        NaN      F    Index
#
#        Magnitude                                  Subject  \
# ...

# %%
filtered_d=df[df['Data_value'].map(lambda x: x >= 100)]
print(filtered_d)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0          RTTA.SF11CA  1997.03     27070.4        NaN      F  Dollars
# 1          RTTA.SF11CA  1998.03     27748.4        NaN      F  Dollars
# 2          RTTA.SF11CA  1999.03     28216.6        NaN      F  Dollars
# 3          RTTA.SF11CA  2000.03     30204.1        NaN      F  Dollars
# 4          RTTA.SF11CA  2001.03     31641.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 26188         RTEQ.SNV  2023.03      1447.0        NaN      F    Index
# 26189         RTEQ.SNV  2023.06      1482.0        NaN      F    Index
# 26190         RTEQ.SNV  2023.09      1507.0        NaN      F    Index
# 26191         RTEQ.SNV  2023.12      1520.0        NaN      F    Index
# 26192         RTEQ.SNV  2024.03      1537.0        NaN      F    Index
#
#        Magnitude                                  Subject  \
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/retail-trade-survey-march-2024-quarter.zip")
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0      RTTA.SF11CA  1997.03     27070.4        NaN      F  Dollars          6
# 1      RTTA.SF11CA  1998.03     27748.4        NaN      F  Dollars          6
# 2      RTTA.SF11CA  1999.03     28216.6        NaN      F  Dollars          6
# 3      RTTA.SF11CA  2000.03     30204.1        NaN      F  Dollars          6
# 4      RTTA.SF11CA  2001.03     31641.6        NaN      F  Dollars          6
#
#                          Subject  \
# 0  Retail Trade (ANZSIC06) - RTT
# 1  Retail Trade (ANZSIC06) - RTT
# 2  Retail Trade (ANZSIC06) - RTT
# 3  Retail Trade (ANZSIC06) - RTT
# 4  Retail Trade (ANZSIC06) - RTT
#
#                                                Group         Series_title_1  \
# 0  Sales and stocks by industry, in current and c...  Core industries total
# 1  Sales and stocks by industry, in current and c...  Core industries total
# ...

# %%
from functools import reduce
if not filtered_d['UNITS'].empty:  # Check if 'age' column is empty
    total = reduce(lambda x, y: x + y, filtered_d['UNITS'])
    print(total)
else:
    print("The filtered DataFrame is empty, cannot calculate total age.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UNITS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head(5)
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1      RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2      RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3      RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4      RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
#
#    Magnitude                        Subject  \
# 0          6  Retail Trade (ANZSIC06) - RTT
# 1          6  Retail Trade (ANZSIC06) - RTT
# 2          6  Retail Trade (ANZSIC06) - RTT
# 3          6  Retail Trade (ANZSIC06) - RTT
# 4          6  Retail Trade (ANZSIC06) - RTT
#
#                                                Group         Series_title_1  \
# 0  Sales and stocks by industry, in current and c...  Core industries total
# 1  Sales and stocks by industry, in current and c...  Core industries total
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/retail trade 1.csv")
df.head(5)
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1      RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2      RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3      RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4      RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
#
#    Magnitude                        Subject  \
# 0          6  Retail Trade (ANZSIC06) - RTT
# 1          6  Retail Trade (ANZSIC06) - RTT
# 2          6  Retail Trade (ANZSIC06) - RTT
# 3          6  Retail Trade (ANZSIC06) - RTT
# 4          6  Retail Trade (ANZSIC06) - RTT
#
#                                                Group         Series_title_1  \
# 0  Sales and stocks by industry, in current and c...  Core industries total
# 1  Sales and stocks by industry, in current and c...  Core industries total
# ...

# %%
df.tail(5)
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 24     RTTA.SF1RNCA  2020.03      9740.6         NaN      F  Dollars
# 25     RTTA.SF1RNCA  2021.03      9893.6         NaN      F  Dollars
# 26     RTTA.SF1RNCA  2022.03     11030.8         NaN      F  Dollars
# 27     RTTA.SF1RNCA  2023.03     11855.4         NaN      F  Dollars
# 28     RTTA.SF1RNCA  2024.03     12273.6         NaN      F  Dollars
#
#     Magnitude                        Subject  \
# 24          6  Retail Trade (ANZSIC06) - RTT
# 25          6  Retail Trade (ANZSIC06) - RTT
# 26          6  Retail Trade (ANZSIC06) - RTT
# 27          6  Retail Trade (ANZSIC06) - RTT
# 28          6  Retail Trade (ANZSIC06) - RTT
#
#                                        Group         Series_title_1  \
# 24  Sales by region in current prices (SAFC)  Core industries total
# 25  Sales by region in current prices (SAFC)  Core industries total
# ...

# %%
df.min()
# Out:
# Series_reference                                          RTTA.SF11CA
# Period                                                        1997.03
# Data_value                                                      844.7
# Suppressed                                                        NaN
# STATUS                                                              F
# UNITS                                                         Dollars
# Magnitude                                                           6
# Subject                                 Retail Trade (ANZSIC06) - RTT
# Group               Sales and stocks by industry, in current and c...
# Series_title_1                                  Core industries total
# Series_title_2                                             Canterbury
# Series_title_3                                                Current
# Series_title_4                                                 Actual
# dtype: object

# %%
import pandas as pd
df=pd.read_csv("/content/retail trade 1.csv")
df.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1      RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2      RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3      RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4      RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
#
#    Magnitude                        Subject  \
# 0          6  Retail Trade (ANZSIC06) - RTT
# 1          6  Retail Trade (ANZSIC06) - RTT
# 2          6  Retail Trade (ANZSIC06) - RTT
# 3          6  Retail Trade (ANZSIC06) - RTT
# 4          6  Retail Trade (ANZSIC06) - RTT
#
#                                                Group         Series_title_1  \
# 0  Sales and stocks by industry, in current and c...  Core industries total
# 1  Sales and stocks by industry, in current and c...  Core industries total
# ...

# %%
df.sum()
# Out:
# Series_reference    RTTA.SF11CARTTA.SF11CARTTA.SF11CARTTA.SF11CART...
# Period                                                       58296.87
# Data_value                                                   562476.9
# Suppressed                                                        0.0
# STATUS                                  FFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# UNITS               DollarsDollarsDollarsDollarsDollarsDollarsDoll...
# Magnitude                                                         174
# Subject             Retail Trade (ANZSIC06) - RTTRetail Trade (ANZ...
# Group               Sales and stocks by industry, in current and c...
# Series_title_1      Core industries totalCore industries totalCore...
# Series_title_2      Sales (operating income)Sales (operating incom...
# Series_title_3      CurrentCurrentCurrentCurrentCurrentCurrentCurr...
# Series_title_4      ActualActualActualActualActualActualActualActu...
# dtype: object

# %%
df.max()
# Out:
# Series_reference                                  RTTA.SF1RNCA
# Period                                                 2024.03
# Data_value                                             43402.0
# Suppressed                                                 NaN
# STATUS                                                       F
# UNITS                                                  Dollars
# Magnitude                                                    6
# Subject                          Retail Trade (ANZSIC06) - RTT
# Group                 Sales by region in current prices (SAFC)
# Series_title_1                           Core industries total
# Series_title_2                                        Taranaki
# Series_title_3      Deflated, at September 2010 quarter prices
# Series_title_4                                          Actual
# dtype: object

# %%
df.count()
# Out:
# Series_reference    29
# Period              29
# Data_value          29
# Suppressed           0
# STATUS              29
# UNITS               29
# Magnitude           29
# Subject             29
# Group               29
# Series_title_1      29
# Series_title_2      29
# Series_title_3      29
# Series_title_4      29
# dtype: int64

# %%
import pandas as pd
data=pd.read_csv("/content/retail trade 1.csv")
grouped_data=data.groupby('Data_value')['Group'].sum()
print(grouped_data)
# Out:
# Data_value
# 844.7               Sales by region in current prices (SAFC)
# 903.1               Sales by region in current prices (SAFC)
# 1437.5              Sales by region in current prices (SAFC)
# 1503.4              Sales by region in current prices (SAFC)
# 1690.9              Sales by region in current prices (SAFC)
# 1724.2              Sales by region in current prices (SAFC)
# 1787.9              Sales by region in current prices (SAFC)
# 2940.9              Sales by region in current prices (SAFC)
# 3094.9              Sales by region in current prices (SAFC)
# 3175.1              Sales by region in current prices (SAFC)
# 9740.6              Sales by region in current prices (SAFC)
# 9893.6              Sales by region in current prices (SAFC)
# 11030.8             Sales by region in current prices (SAFC)
# 11855.4             Sales by region in current prices (SAFC)
# 12273.6             Sales by region in current prices (SAFC)
# ...

# %%
import pandas as pd
d=pd.read_csv("/content/retail trade 1.csv")
d['Series_title_1'],d['Series_title_2'].map(lambda x : x *2)
print(df)
filtered_d= d[d['Data_value'].map(lambda x :x < 3000)]
print(filtered_d)
from functools import reduce
if not filtered_d['Data_value'].empty: # Check if 'Data_value' column is empty
    total = reduce(lambda x, y : x + y, filtered_d['Data_value'])
    print(total)
else:
  print("the filtered DataFrame is empty, cannot calculate total Data_value")
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       RTTA.SF11CA  1997.03     27070.4         NaN      F  Dollars
# 1       RTTA.SF11CA  1998.03     27748.4         NaN      F  Dollars
# 2       RTTA.SF11CA  1999.03     28216.6         NaN      F  Dollars
# 3       RTTA.SF11CA  2000.03     30204.1         NaN      F  Dollars
# 4       RTTA.SF11CA  2001.03     31641.6         NaN      F  Dollars
# 5       RTTA.SF11CA  2002.03     33853.0         NaN      F  Dollars
# 6       RTTA.SF11CA  2003.03     36284.6         NaN      F  Dollars
# 7       RTTA.SF11CA  2004.03     38184.9         NaN      F  Dollars
# 8       RTTA.SF11KA  1999.03     35371.2         NaN      F  Dollars
# 9       RTTA.SF11KA  2000.03     37506.9         NaN      F  Dollars
# 10      RTTA.SF11KA  2001.03     38269.6         NaN      F  Dollars
# 11      RTTA.SF11KA  2002.03     39423.6         NaN      F  Dollars
# 12      RTTA.SF11KA  2003.03     41403.4         NaN      F  Dollars
# ...

# %%
import pandas as pd
d=pd.read_csv("/content/retail trade 1.csv")
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,15))

# %%
#1 Line plot
plt.subplot(2,3,1)
plt.plot(df['Series_reference'],df['Magnitude'])
plt.title("LINE PLOT")
plt.xlabel("Series_reference")
plt.ylabel("Magnitude")
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
#2. Bar plot
plt.subplot(2, 3, 2)
plt.bar(df['Series_reference'], df['Data_value'])
plt.title("BAR PLOT")
plt.xlabel('Series_reference')
plt.ylabel('Data_value')
# Out:
# Text(0, 0.5, 'Data_value')

# %%
plt.hist(d['Period'],bins=10,alpha=0.7,color='green')
plt.title('Period Score Distribution')
plt.xlabel('Period')
plt.ylabel('Frequency')
plt.show()

# %%
#4. Scatter plot
plt.subplot(2, 3, 4)
plt.scatter(df['Data_value'], df['Series_reference'])
plt.title("SCATTER PLOT")
plt.xlabel('Data_value')
plt.ylabel('Series_reference')
# Out:
# Text(0, 0.5, 'Phone 1')

# %%
import pandas as pd
d=pd.read_csv("/content/retail trade 1.csv")
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,15))

# %%
#5. Box plot
plt.figure(figsize=(10, 6))
d.boxplot(column=['Period'])
plt.title("BOX PLOT")
plt.ylabel('Phone 2')
# Out:
# Text(0, 0.5, 'Phone 2')

# %%
#6. pie chart
plt.subplot(2, 3, 6)
plt.pie(d['Period'], labels=d['Subject'], autopct='%1.1f%%')
plt.title('PIF CHART')
# Out:
# Text(0.5, 1.0, 'PIF CHART')
